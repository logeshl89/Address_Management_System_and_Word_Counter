# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv5 on Custom Objects
#
# **⚠️ This notebook was updated on October 24th, 2023. Since then, the way to load data into the notebook has changed. Thus, this notebook is not the same as the original version used in the accompanying YouTube video or blog post.**
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install YOLOv5 dependencies
# * Download custom YOLOv5 object detection data
# * Write our YOLOv5 Training configuration
# * Run YOLOv5 training
# * Evaluate YOLOv5 performance
# * Visualize YOLOv5 training data
# * Run YOLOv5 inference on test images
# * Export saved YOLOv5 weights for future inference
#
# Let's get started!

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 064365d8683fd002e9ad789c1e91fa3d021b44f0
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# HEAD is now at 064365d8 Update parse_opt() in export.py to work as in train.py (#10789)

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.3.0+cu121 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 200,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)
#
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a supported format, the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v5 PyTorch` dataset format.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# ## Step 6: Download a Dataset
#
# Add your Roboflow API key below to download the default money counting dataset. Alternatively, use the code provided by the Roboflow dashboard in the above step to load a custom dataset.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NRcKeqAVLUydG0oNYfwe")
project = rf.workspace("kathiravan-matric-higher-secondary-school").project("object_detection_target")
version = project.version(4)
dataset = version.download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.29)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Object_detection_target-4 to yolov5pytorch:: 100%|██████████| 22187/22187 [00:00<00:00, 22879.43it/s]
# Extracting Dataset Version Zip to Object_detection_target-4 in yolov5pytorch:: 100%|██████████| 1218/1218 [00:00<00:00, 3775.41it/s]

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat {dataset.location}/data.yaml
# Out:
# names:
# - Target
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: object_detection_target
#   url: https://universe.roboflow.com/kathiravan-matric-higher-secondary-school/object_detection_target/dataset/4
#   version: 4
#   workspace: kathiravan-matric-higher-secondary-school
# test: ../test/images
# train: Object_detection_target-4/train/images
# val: Object_detection_target-4/valid/images

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open(dataset.location + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#this is the model configuration we will use for our tutorial
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 100 --data {dataset.location}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# 2024-05-24 08:02:02.056755: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-24 08:02:02.056811: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-24 08:02:02.058510: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-24 08:02:02.066627: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-24 08:02:03.768148: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=, cfg=./models/custom_yolov5s.yaml, data=/content/yolov5/Object_detection_target-4/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 242 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-72-g064365d8 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 19.1MB/s]
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 233 layers, 7255094 parameters, 7255094 gradients
#
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 59 weight(decay=0.0), 70 weight(decay=0.0005), 62 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov5/Object_detection_target-4/train/labels... 423 images, 110 backgrounds, 0 corrupt: 100% 423/423 [00:00<00:00, 1948.76it/s]
# train: New cache created: /content/yolov5/Object_detection_target-4/train/labels.cache
# train: Caching images (0.2GB ram): 100% 423/423 [00:02<00:00, 182.86it/s]
# val: Scanning /content/yolov5/Object_detection_target-4/valid/labels... 121 images, 36 backgrounds, 0 corrupt: 100% 121/121 [00:00<00:00, 639.28it/s]
# val: New cache created: /content/yolov5/Object_detection_target-4/valid/labels.cache
# val: Caching images (0.1GB ram): 100% 121/121 [00:01<00:00, 100.91it/s]
#
# AutoAnchor: 3.32 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/yolov5s_results/labels.jpg...
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99      1.67G     0.1007    0.01698          0         14        416: 100% 27/27 [00:08<00:00,  3.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.03s/it]
#                    all        121         85   0.000468        0.2   0.000473   7.69e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      1.97G    0.09946    0.01741          0          9        416: 100% 27/27 [00:06<00:00,  4.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.04it/s]
#                    all        121         85    0.00231      0.988    0.00308    0.00134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      1.97G    0.09504    0.01818          0         14        416: 100% 27/27 [00:03<00:00,  7.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.08it/s]
#                    all        121         85    0.00223      0.953    0.00561    0.00164
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      1.97G      0.094    0.01891          0         17        416: 100% 27/27 [00:05<00:00,  5.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.66it/s]
#                    all        121         85    0.00234          1     0.0157    0.00388
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      1.97G     0.0837    0.01906          0         15        416: 100% 27/27 [00:03<00:00,  7.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.61it/s]
#                    all        121         85     0.0214     0.0353     0.0234    0.00546
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      1.97G    0.07581    0.01929          0         14        416: 100% 27/27 [00:03<00:00,  7.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.76it/s]
#                    all        121         85     0.0274      0.271     0.0243    0.00816
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      1.97G    0.06973    0.02054          0         13        416: 100% 27/27 [00:05<00:00,  4.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.00it/s]
#                    all        121         85       0.15      0.694      0.142     0.0455
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      1.97G    0.06629    0.01956          0         12        416: 100% 27/27 [00:03<00:00,  7.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.92it/s]
#                    all        121         85     0.0654      0.084     0.0896     0.0358
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      1.97G    0.06618    0.01936          0          8        416: 100% 27/27 [00:03<00:00,  8.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.76it/s]
#                    all        121         85      0.268      0.259      0.165     0.0393
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      1.97G    0.06363    0.01887          0          8        416: 100% 27/27 [00:05<00:00,  4.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.25it/s]
#                    all        121         85     0.0833      0.859      0.147     0.0537
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      1.97G    0.05605    0.01854          0         14        416: 100% 27/27 [00:03<00:00,  7.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.81it/s]
#                    all        121         85      0.141      0.675      0.159     0.0497
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      1.97G    0.05984    0.01816          0         13        416: 100% 27/27 [00:03<00:00,  7.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.91it/s]
#                    all        121         85      0.177      0.424      0.268     0.0802
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      1.97G    0.05402    0.01841          0         16        416: 100% 27/27 [00:05<00:00,  5.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.44it/s]
#                    all        121         85     0.0373      0.412     0.0319    0.00979
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/99      1.97G    0.05291    0.01876          0         13        416: 100% 27/27 [00:03<00:00,  7.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.09it/s]
#                    all        121         85      0.142      0.332       0.13     0.0309
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/99      1.97G    0.05472    0.01783          0         11        416: 100% 27/27 [00:03<00:00,  8.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.91it/s]
#                    all        121         85      0.301      0.729      0.345      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/99      1.97G    0.05115    0.01882          0         11        416: 100% 27/27 [00:04<00:00,  5.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.56it/s]
#                    all        121         85      0.181      0.529      0.228     0.0648
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/99      1.97G    0.04811    0.01782          0         11        416: 100% 27/27 [00:04<00:00,  5.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.20it/s]
#                    all        121         85      0.247      0.882      0.353     0.0979
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/99      1.97G     0.0476    0.01769          0         11        416: 100% 27/27 [00:03<00:00,  8.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.07it/s]
#                    all        121         85      0.435      0.976      0.565      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/99      1.97G    0.04468    0.01632          0         11        416: 100% 27/27 [00:03<00:00,  7.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.48it/s]
#                    all        121         85      0.481      0.965      0.499       0.23
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/99      1.97G    0.04788    0.01784          0         14        416: 100% 27/27 [00:04<00:00,  5.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.18it/s]
#                    all        121         85        0.4      0.738      0.447      0.138
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/99      1.97G    0.04386     0.0165          0         11        416: 100% 27/27 [00:03<00:00,  8.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.38it/s]
#                    all        121         85      0.175      0.729      0.183     0.0481
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/99      1.97G    0.04708     0.0163          0         11        416: 100% 27/27 [00:04<00:00,  6.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.54it/s]
#                    all        121         85      0.331      0.682      0.376     0.0891
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/99      1.97G    0.04209    0.01586          0         11        416: 100% 27/27 [00:05<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.23it/s]
#                    all        121         85      0.622      0.894      0.658      0.238
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/99      1.97G    0.04303    0.01697          0         13        416: 100% 27/27 [00:03<00:00,  7.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.31it/s]
#                    all        121         85      0.649      0.871      0.691      0.292
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/99      1.97G    0.04168    0.01663          0         15        416: 100% 27/27 [00:03<00:00,  8.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.67it/s]
#                    all        121         85      0.634      0.882      0.683      0.338
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/99      1.97G    0.04346    0.01577          0         12        416: 100% 27/27 [00:06<00:00,  4.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.01it/s]
#                    all        121         85      0.603      0.927      0.657      0.216
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/99      1.97G    0.03998    0.01682          0         15        416: 100% 27/27 [00:03<00:00,  7.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.04it/s]
#                    all        121         85      0.692          1      0.738      0.358
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/99      1.97G    0.03779    0.01529          0         12        416: 100% 27/27 [00:03<00:00,  7.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.70it/s]
#                    all        121         85     0.0759        0.6     0.0817     0.0417
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/99      1.97G    0.03729     0.0162          0         16        416: 100% 27/27 [00:05<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.58it/s]
#                    all        121         85       0.57      0.894        0.6      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/99      1.97G    0.03718    0.01535          0         15        416: 100% 27/27 [00:03<00:00,  7.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.06it/s]
#                    all        121         85      0.734      0.953      0.796      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/99      1.97G     0.0356    0.01464          0         14        416: 100% 27/27 [00:03<00:00,  8.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.27it/s]
#                    all        121         85      0.647      0.894      0.704      0.316
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/99      1.97G    0.03438    0.01458          0         13        416: 100% 27/27 [00:05<00:00,  4.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.34it/s]
#                    all        121         85      0.688      0.847      0.715      0.445
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/99      1.97G    0.03788    0.01479          0         13        416: 100% 27/27 [00:04<00:00,  6.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.97it/s]
#                    all        121         85      0.783          1      0.829      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/99      1.97G    0.03593    0.01454          0         15        416: 100% 27/27 [00:03<00:00,  7.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.19it/s]
#                    all        121         85      0.529      0.831      0.621      0.328
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/99      1.97G    0.03286    0.01425          0          9        416: 100% 27/27 [00:04<00:00,  6.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.60it/s]
#                    all        121         85      0.767      0.953      0.835      0.415
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/99      1.97G    0.03477     0.0136          0         13        416: 100% 27/27 [00:05<00:00,  5.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.87it/s]
#                    all        121         85      0.772          1       0.85      0.645
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/99      1.97G    0.03344     0.0136          0         16        416: 100% 27/27 [00:03<00:00,  7.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.33it/s]
#                    all        121         85      0.799      0.988       0.84      0.474
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/99      1.97G    0.03517    0.01296          0         14        416: 100% 27/27 [00:03<00:00,  7.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.64it/s]
#                    all        121         85      0.764          1      0.831      0.494
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/99      1.97G    0.03343    0.01318          0         14        416: 100% 27/27 [00:05<00:00,  5.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.30it/s]
#                    all        121         85      0.802      0.929       0.83      0.381
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/99      1.97G    0.03158    0.01344          0         12        416: 100% 27/27 [00:03<00:00,  7.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.20it/s]
#                    all        121         85      0.765          1       0.81      0.534
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/99      1.97G    0.03054    0.01315          0         13        416: 100% 27/27 [00:03<00:00,  7.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.81it/s]
#                    all        121         85      0.795          1      0.861      0.561
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/99      1.97G    0.03264    0.01296          0         13        416: 100% 27/27 [00:05<00:00,  4.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.81it/s]
#                    all        121         85      0.816          1       0.92      0.603
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/99      1.97G    0.03435    0.01212          0         11        416: 100% 27/27 [00:03<00:00,  7.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.08it/s]
#                    all        121         85      0.814          1      0.922       0.65
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/99      1.97G    0.02837    0.01185          0         11        416: 100% 27/27 [00:03<00:00,  7.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.05it/s]
#                    all        121         85      0.805          1      0.901      0.713
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/99      1.97G    0.03069    0.01242          0          9        416: 100% 27/27 [00:07<00:00,  3.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.97it/s]
#                    all        121         85      0.726          1      0.809      0.569
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/99      1.97G    0.03228    0.01264          0         15        416: 100% 27/27 [00:03<00:00,  7.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.99it/s]
#                    all        121         85      0.807          1      0.867      0.681
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/99      1.97G    0.03063    0.01204          0         15        416: 100% 27/27 [00:03<00:00,  7.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.14it/s]
#                    all        121         85      0.815          1      0.906      0.587
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/99      1.97G    0.02903    0.01148          0          8        416: 100% 27/27 [00:05<00:00,  4.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.48it/s]
#                    all        121         85      0.809          1      0.896      0.642
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/99      1.97G    0.03006    0.01137          0         13        416: 100% 27/27 [00:03<00:00,  6.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.14it/s]
#                    all        121         85      0.763          1      0.852      0.704
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/99      1.97G    0.02814    0.01151          0         15        416: 100% 27/27 [00:03<00:00,  8.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.12it/s]
#                    all        121         85      0.807          1      0.878      0.661
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/99      1.97G    0.02845    0.01147          0          8        416: 100% 27/27 [00:05<00:00,  4.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.48it/s]
#                    all        121         85      0.809      0.998      0.844      0.584
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/99      1.97G    0.02881     0.0119          0         12        416: 100% 27/27 [00:04<00:00,  6.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.17it/s]
#                    all        121         85      0.809          1       0.93      0.623
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/99      1.97G    0.02741    0.01109          0         15        416: 100% 27/27 [00:03<00:00,  7.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.90it/s]
#                    all        121         85      0.814          1       0.94      0.731
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/99      1.97G    0.02746    0.01096          0          8        416: 100% 27/27 [00:04<00:00,  6.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.27it/s]
#                    all        121         85      0.807          1      0.918      0.675
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/99      1.97G    0.02798     0.0111          0          9        416: 100% 27/27 [00:05<00:00,  5.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.14it/s]
#                    all        121         85      0.809      0.995      0.933      0.693
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/99      1.97G    0.02822    0.01096          0         11        416: 100% 27/27 [00:03<00:00,  7.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.22it/s]
#                    all        121         85      0.794      0.995      0.891      0.591
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/99      1.97G     0.0272    0.01176          0         15        416: 100% 27/27 [00:03<00:00,  7.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.58it/s]
#                    all        121         85      0.766          1      0.827      0.541
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/99      1.97G    0.02756    0.01097          0         17        416: 100% 27/27 [00:06<00:00,  4.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.81it/s]
#                    all        121         85      0.808          1      0.856      0.702
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/99      1.97G     0.0279    0.01121          0         15        416: 100% 27/27 [00:03<00:00,  7.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.24it/s]
#                    all        121         85      0.793       0.99      0.851      0.596
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/99      1.97G    0.02575    0.01108          0         12        416: 100% 27/27 [00:03<00:00,  7.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.17it/s]
#                    all        121         85      0.809          1      0.826      0.631
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       60/99      1.97G     0.0236    0.01052          0         12        416: 100% 27/27 [00:05<00:00,  4.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.35it/s]
#                    all        121         85      0.817          1      0.934      0.711
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       61/99      1.97G    0.02609    0.01104          0         11        416: 100% 27/27 [00:03<00:00,  7.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.08it/s]
#                    all        121         85      0.824      0.991      0.969      0.732
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       62/99      1.97G    0.02548    0.01094          0         10        416: 100% 27/27 [00:03<00:00,  8.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.14it/s]
#                    all        121         85      0.825          1      0.951      0.724
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       63/99      1.97G    0.02509    0.01026          0         13        416: 100% 27/27 [00:04<00:00,  5.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.28it/s]
#                    all        121         85      0.797          1      0.878      0.729
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       64/99      1.97G    0.02409    0.01067          0         12        416: 100% 27/27 [00:04<00:00,  6.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.96it/s]
#                    all        121         85      0.807          1      0.882      0.675
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       65/99      1.97G    0.02405    0.01092          0         12        416: 100% 27/27 [00:03<00:00,  7.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.23it/s]
#                    all        121         85      0.808          1      0.848      0.611
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       66/99      1.97G    0.02424    0.01124          0         17        416: 100% 27/27 [00:04<00:00,  6.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.62it/s]
#                    all        121         85      0.816          1      0.929      0.666
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       67/99      1.97G      0.027    0.01025          0         13        416: 100% 27/27 [00:05<00:00,  5.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.12it/s]
#                    all        121         85      0.813          1      0.844      0.615
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       68/99      1.97G    0.02511    0.01086          0         15        416: 100% 27/27 [00:03<00:00,  7.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.17it/s]
#                    all        121         85      0.838       0.97      0.904      0.677
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       69/99      1.97G    0.02402    0.01026          0          9        416: 100% 27/27 [00:03<00:00,  7.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.73it/s]
#                    all        121         85      0.847      0.978      0.895      0.602
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       70/99      1.97G    0.02293    0.01055          0         11        416: 100% 27/27 [00:06<00:00,  4.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.13it/s]
#                    all        121         85      0.817          1      0.932      0.568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       71/99      1.97G    0.02259     0.0101          0         14        416: 100% 27/27 [00:03<00:00,  8.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.18it/s]
#                    all        121         85      0.823          1      0.912      0.711
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       72/99      1.97G    0.02333    0.00983          0         10        416: 100% 27/27 [00:03<00:00,  8.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.16it/s]
#                    all        121         85      0.822          1       0.92      0.669
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       73/99      1.97G    0.02297    0.01024          0         18        416: 100% 27/27 [00:05<00:00,  4.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.36it/s]
#                    all        121         85      0.808          1      0.913      0.698
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       74/99      1.97G    0.02291   0.009554          0         11        416: 100% 27/27 [00:03<00:00,  7.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.06it/s]
#                    all        121         85      0.805          1      0.834      0.663
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       75/99      1.97G    0.02406    0.01035          0         14        416: 100% 27/27 [00:03<00:00,  7.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.12it/s]
#                    all        121         85      0.816          1      0.921      0.757
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       76/99      1.97G    0.02081   0.009667          0         14        416: 100% 27/27 [00:05<00:00,  5.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.55it/s]
#                    all        121         85      0.817          1      0.904      0.706
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       77/99      1.97G    0.02159   0.009288          0          9        416: 100% 27/27 [00:03<00:00,  7.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.02it/s]
#                    all        121         85      0.814          1      0.851      0.698
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       78/99      1.97G    0.02341   0.009492          0          9        416: 100% 27/27 [00:03<00:00,  7.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.11it/s]
#                    all        121         85      0.817          1      0.836      0.663
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       79/99      1.97G    0.02138   0.009156          0         18        416: 100% 27/27 [00:04<00:00,  5.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.48it/s]
#                    all        121         85      0.816          1      0.827      0.628
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       80/99      1.97G    0.02312   0.009835          0         12        416: 100% 27/27 [00:04<00:00,  6.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.19it/s]
#                    all        121         85      0.816          1      0.847       0.67
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       81/99      1.97G    0.01939   0.009464          0          8        416: 100% 27/27 [00:03<00:00,  8.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.06it/s]
#                    all        121         85      0.817          1      0.899      0.709
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       82/99      1.97G    0.02163   0.009347          0         12        416: 100% 27/27 [00:04<00:00,  6.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.49it/s]
#                    all        121         85      0.817          1      0.869      0.691
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       83/99      1.97G    0.02046   0.009223          0         12        416: 100% 27/27 [00:05<00:00,  4.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.04it/s]
#                    all        121         85      0.816          1      0.882      0.701
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       84/99      1.97G    0.01919     0.0095          0          8        416: 100% 27/27 [00:03<00:00,  8.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.09it/s]
#                    all        121         85      0.816          1      0.872      0.693
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       85/99      1.97G    0.01971    0.00981          0         13        416: 100% 27/27 [00:03<00:00,  7.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.22it/s]
#                    all        121         85      0.815          1      0.891      0.729
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       86/99      1.97G    0.02189    0.00941          0         14        416: 100% 27/27 [00:05<00:00,  4.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.34it/s]
#                    all        121         85      0.808          1      0.855      0.707
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       87/99      1.97G    0.01845   0.009411          0         10        416: 100% 27/27 [00:03<00:00,  7.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.06it/s]
#                    all        121         85      0.808          1      0.827      0.689
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       88/99      1.97G    0.02185    0.00919          0         12        416: 100% 27/27 [00:03<00:00,  7.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.07it/s]
#                    all        121         85      0.819          1      0.902      0.715
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       89/99      1.97G    0.02337   0.009841          0         12        416: 100% 27/27 [00:09<00:00,  2.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.47it/s]
#                    all        121         85      0.902      0.988      0.983      0.741
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       90/99      1.97G    0.01905   0.009325          0         13        416: 100% 27/27 [00:03<00:00,  7.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.15it/s]
#                    all        121         85      0.825          1      0.947      0.778
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       91/99      1.97G    0.02073   0.009256          0         10        416: 100% 27/27 [00:03<00:00,  7.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.51it/s]
#                    all        121         85      0.824          1      0.926      0.756
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       92/99      1.97G    0.01951    0.00955          0         15        416: 100% 27/27 [00:05<00:00,  4.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.28it/s]
#                    all        121         85      0.817          1      0.863      0.717
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       93/99      1.97G     0.0209   0.009882          0         16        416: 100% 27/27 [00:03<00:00,  7.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.12it/s]
#                    all        121         85      0.817          1      0.868      0.709
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       94/99      1.97G     0.0197    0.00945          0         11        416: 100% 27/27 [00:03<00:00,  7.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  4.98it/s]
#                    all        121         85      0.862      0.976      0.953       0.79
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       95/99      1.97G    0.01801   0.009066          0          8        416: 100% 27/27 [00:05<00:00,  5.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.25it/s]
#                    all        121         85      0.858      0.976      0.977      0.796
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       96/99      1.97G    0.02045   0.008802          0          9        416: 100% 27/27 [00:04<00:00,  6.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.11it/s]
#                    all        121         85      0.862      0.953      0.968      0.786
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       97/99      1.97G    0.02247   0.008601          0         13        416: 100% 27/27 [00:03<00:00,  7.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.17it/s]
#                    all        121         85      0.824          1      0.947       0.78
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       98/99      1.97G    0.02013   0.008784          0         10        416: 100% 27/27 [00:04<00:00,  5.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.35it/s]
#                    all        121         85      0.819          1      0.917      0.746
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       99/99      1.97G     0.0192   0.009437          0         17        416: 100% 27/27 [00:04<00:00,  5.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:00<00:00,  5.07it/s]
#                    all        121         85      0.817          1      0.876      0.712
#
# 100 epochs completed in 0.164 hours.
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.8MB
#
# Validating runs/train/yolov5s_results/weights/best.pt...
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7246518 parameters, 0 gradients
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.58it/s]
#                    all        121         85      0.857      0.984      0.977      0.796
# Results saved to runs/train/yolov5s_results
# CPU times: user 7.08 s, sys: 794 ms, total: 7.87 s
# Wall time: 10min 28s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance
#
# > Add blockquote

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch1.jpg', width=900)

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %% [markdown]
# # Run Inference With Trained Weights
#
# Next, we can run inference with a pretrained checkpoint on all images in the `test/images` folder to understand how our model performs on our test set.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results/weights
# Out:
# best.pt  last.pt

# %% [markdown]
# In the snippet below, replace `Cash-Counter-10` with the name of the folder in which your dataset is stored.

# %%
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source /content/yolov5/Object_detection_target-4/test/images
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_results/weights/best.pt'], source=/content/yolov5/Object_detection_target-4/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d8 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7246518 parameters, 0 gradients
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00017_png.rf.ba5c913a5329071066a50a18df30b193.jpg: 416x416 1 Target, 7.7ms
# image 2/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00022_png.rf.33f755800c30d7dbff82b98164ae41be.jpg: 416x416 1 Target, 7.7ms
# image 3/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00137_png.rf.9c7eedeae80681d70004100e4471f217.jpg: 416x416 1 Target, 7.7ms
# image 4/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00142_png.rf.fa700a3f3fb9a1886d6d31d5abcfaf4c.jpg: 416x416 1 Target, 7.7ms
# image 5/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00171_png.rf.3164aeaa4f9e055d75aeb61e0fd8afed.jpg: 416x416 1 Target, 8.4ms
# image 6/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00173_png.rf.ec0bc20ada077e3bc5852f68648a42c9.jpg: 416x416 1 Target, 7.6ms
# image 7/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00182_png.rf.3a5887c26630118e74ec97190a94767b.jpg: 416x416 1 Target, 7.6ms
# image 8/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00196_png.rf.d79aeae6937501cf3092e3a2e99d9017.jpg: 416x416 1 Target, 7.6ms
# image 9/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00200_png.rf.7ac0e77dbb7ceb7addb07a6cf2e1d5b5.jpg: 416x416 1 Target, 7.6ms
# image 10/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00204_png.rf.8992773042f2a77f281e5afb5ed9f441.jpg: 416x416 1 Target, 10.3ms
# image 11/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00206_png.rf.80b6cbfad46a59c19cdf363cd7e424ad.jpg: 416x416 1 Target, 7.6ms
# image 12/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00215_png.rf.18d6036c4cea67a5d8b698cbc7cbc407.jpg: 416x416 1 Target, 7.6ms
# image 13/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00229_png.rf.ae2e74695ed6907764f09b8eda7cb08e.jpg: 416x416 1 Target, 7.6ms
# image 14/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00238_png.rf.17134c7583836c32f45ad231d02459c5.jpg: 416x416 1 Target, 7.6ms
# image 15/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00239_png.rf.5dfeacea9b1963b1d4ec1f66e7f879e0.jpg: 416x416 1 Target, 7.6ms
# image 16/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00242_png.rf.aaeb998773f8623f86ea249b84d7dd43.jpg: 416x416 1 Target, 7.6ms
# image 17/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00255_png.rf.3039a99a90e0fdbba3d2145dee224bdf.jpg: 416x416 1 Target, 7.7ms
# image 18/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00264_png.rf.7c20cef665acf70eb0a8a69f93da3516.jpg: 416x416 1 Target, 11.2ms
# image 19/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00266_png.rf.583b61f6d26ac9fe27e145eefa2b6efe.jpg: 416x416 1 Target, 7.6ms
# image 20/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00284_png.rf.a35c6d52fc006a444d6326f18bdbf72c.jpg: 416x416 1 Target, 7.7ms
# image 21/59 /content/yolov5/Object_detection_target-4/test/images/Main-02_00285_png.rf.588a3c321f0ded7eb189be59162b5707.jpg: 416x416 1 Target, 7.6ms
# image 22/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00003_png.rf.b2102ce79918d47e54228afedc443e3c.jpg: 416x416 1 Target, 7.6ms
# image 23/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00004_png.rf.71b2d83f6fb4e7a7c2c996f346619a1b.jpg: 416x416 1 Target, 7.7ms
# image 24/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00015_png.rf.d6ff0e730e6ad25a518671fed4ad8de9.jpg: 416x416 1 Target, 7.6ms
# image 25/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00032_png.rf.aa3bb8cf9337bf208545108de369db8e.jpg: 416x416 1 Target, 7.6ms
# image 26/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00126_png.rf.9fd526b450f19e02871d71c450774579.jpg: 416x416 1 Target, 7.6ms
# image 27/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00133_png.rf.4ea5b70996f9262bcd964a3b9a0b322f.jpg: 416x416 1 Target, 7.6ms
# image 28/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00135_png.rf.e8f84b878f104c21340a170f911f00c6.jpg: 416x416 1 Target, 7.7ms
# image 29/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00147_png.rf.b82bd1ab2056a4ba6f605a594c91785e.jpg: 416x416 1 Target, 7.6ms
# image 30/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00155_png.rf.627372e7d44494f3ddf27e1abd52cb7b.jpg: 416x416 1 Target, 7.6ms
# image 31/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00175_png.rf.35d53bc8dc665dce33b5b1e3e1bd2212.jpg: 416x416 1 Target, 7.6ms
# image 32/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00179_png.rf.b5ad140b106e4ec29ea0fb07e39c1206.jpg: 416x416 1 Target, 7.7ms
# image 33/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00190_png.rf.184ea41ddc25469699f10f04b05d137d.jpg: 416x416 1 Target, 7.6ms
# image 34/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00196_png.rf.50291e09697035cf1463ef3526079030.jpg: 416x416 1 Target, 7.6ms
# image 35/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00207_png.rf.090ea7d2e757a8a739c32b410a939e5e.jpg: 416x416 1 Target, 7.7ms
# image 36/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00208_png.rf.a8ab2ad28d78427a0050e1ac56b2539f.jpg: 416x416 1 Target, 7.7ms
# image 37/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00224_png.rf.0fd75f1a2d571f53a7a29be34064521d.jpg: 416x416 1 Target, 7.6ms
# image 38/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00227_png.rf.17b3f4dcc8447739addf141ff0c6618a.jpg: 416x416 1 Target, 7.6ms
# image 39/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00228_png.rf.9d47871bb9ee40b2c94a0f8287555ee4.jpg: 416x416 1 Target, 7.6ms
# image 40/59 /content/yolov5/Object_detection_target-4/test/images/Main-1_00239_png.rf.68c66ec7bab42ab9a8e4ee8e638651d6.jpg: 416x416 1 Target, 7.6ms
# image 41/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00004_png.rf.76c0ca8112ed261b7c012b361afb75f0.jpg: 416x416 1 Target, 7.6ms
# image 42/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00011_png.rf.a2dba298c48ec9b07e10a65abaefb832.jpg: 416x416 1 Target, 7.6ms
# image 43/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00014_png.rf.b751606aa929044258ba34122c90e0c9.jpg: 416x416 1 Target, 7.6ms
# image 44/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00016_png.rf.c0a404b5796322af91827985796fb68c.jpg: 416x416 1 Target, 7.6ms
# image 45/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00030_png.rf.555b86605a63897a46a05af3460c3d29.jpg: 416x416 1 Target, 7.6ms
# image 46/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00060_png.rf.8c97b57fa1269297b1ccdb75f822c2e4.jpg: 416x416 1 Target, 7.6ms
# image 47/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00063_png.rf.6e0fd043ea7c0a9cdccf39389a973d33.jpg: 416x416 1 Target, 7.6ms
# image 48/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00077_png.rf.3607401a9e6208813f39e8d90b91b896.jpg: 416x416 1 Target, 7.6ms
# image 49/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00104_png.rf.cf00e825b47b277cd3af1ce59f43adf4.jpg: 416x416 (no detections), 8.7ms
# image 50/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00123_png.rf.05a1b84f2cbc3a4ac5a052d2c2af49f9.jpg: 416x416 (no detections), 7.6ms
# image 51/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00142_png.rf.737fed4a7603affd0145e2bd472643e9.jpg: 416x416 (no detections), 7.8ms
# image 52/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00143_png.rf.a355aa821f23289bb9201ac219636ada.jpg: 416x416 (no detections), 7.6ms
# image 53/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00147_png.rf.6447f15e2cd75c8b2f92b195a8957498.jpg: 416x416 (no detections), 7.6ms
# image 54/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00150_png.rf.474910f014f741ec01cbfc06dda467ff.jpg: 416x416 (no detections), 7.7ms
# image 55/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00156_png.rf.2fecd5c4d1ccd859cd01ea5ed771645f.jpg: 416x416 (no detections), 7.7ms
# image 56/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00166_png.rf.6993da50178439f1695c5d51b5b6662e.jpg: 416x416 (no detections), 7.6ms
# image 57/59 /content/yolov5/Object_detection_target-4/test/images/Main-i_00177_png.rf.32b5b17322e7375713e99f61ae0ac075.jpg: 416x416 (no detections), 7.6ms
# image 58/59 /content/yolov5/Object_detection_target-4/test/images/Main_00010_png.rf.26c6d8971400888c7919b94e12fe9cae.jpg: 416x416 1 Target, 7.6ms
# image 59/59 /content/yolov5/Object_detection_target-4/test/images/Main_00013_png.rf.f980c1268409b8e93869b35231daf08a.jpg: 416x416 1 Target, 7.6ms
# Speed: 0.3ms pre-process, 7.8ms inference, 13.5ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp5

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp3/*.jpg')[:10]: #assuming JPG
    display(Image(filename=imageName))

# %% [markdown]
# ## Deploy Model on Roboflow
#
# Once you have finished training your YOLOv5 model, you’ll have a set of trained weights ready for use. These weights will be in the `/content/yolov5/runs/train/yolov5s_results/` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv5 weights.
#
# **Before you run this code, make sure you create a new Version in the Roboflow dashboard following the instructions we covered earlier. Fill in your project name, workspace, and version number below.**
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
rf = Roboflow(api_key="NRcKeqAVLUydG0oNYfwe")
project = rf.workspace("kathiravan-matric-higher-secondary-school").project("object_detection_target")
dataset = version.download("yolov5")


project.version(dataset.version).deploy(model_type="yolov5", model_path=f"/content/yolov5/runs/train/yolov5s_results/")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API

#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on Main-i_00156_png.rf.2fecd5c4d1ccd859cd01ea5ed771645f.jpg
# {'predictions': [], 'image': {'width': '640', 'height': '640'}}

# %%
from yolov5 import detect
source_path = "/content/1_1956000.png"
custom_weights_path = "runs/train/yolov5s_results/weights/best.pt"
conf = 0.5
iou = 0.4
detect(source_path, custom_weights_path, conf=conf, iou=iou)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-106f8546cbfb> in <cell line: 6>()
#       4 conf = 0.5
#       5 iou = 0.4
# ----> 6 detect(source_path, custom_weights_path, conf=conf, iou=iou)
#
# TypeError: 'module' object is not callable

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
# iou_threshold = 0.5
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_threshold,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
